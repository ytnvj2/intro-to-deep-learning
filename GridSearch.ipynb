# %%
import numpy as np
import matplotlib.pyplot as plt
def get_spiral():
    # Idea: radius -> low...high
    #           (don't start at 0, otherwise points will be "mushed" at origin)
    #       angle = low...high proportional to radius
    #               [0, 2pi/6, 4pi/6, ..., 10pi/6] --> [pi/2, pi/3 + pi/2, ..., ]
    # x = rcos(theta), y = rsin(theta) as usual

    radius = np.linspace(1, 10, 100)
    thetas = np.empty((6, 100))
    for i in range(6):
        start_angle = np.pi*i / 3.0
        end_angle = start_angle + np.pi / 2
        points = np.linspace(start_angle, end_angle, 100)
        thetas[i] = points

    # convert into cartesian coordinates
    x1 = np.empty((6, 100))
    x2 = np.empty((6, 100))
    for i in range(6):
        x1[i] = radius * np.cos(thetas[i])
        x2[i] = radius * np.sin(thetas[i])

    # inputs
    X = np.empty((600, 2))
    X[:,0] = x1.flatten()
    X[:,1] = x2.flatten()

    # add noise
    X += np.random.randn(600, 2)*0.5

    # targets
    Y = np.array([0]*100 + [1]*100 + [0]*100 + [1]*100 + [0]*100 + [1]*100)
    return X, Y

# %%
X,y=get_spiral()

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
 ! pip install theano
# Out:
# Collecting theano
#   Downloading https://files.pythonhosted.org/packages/4d/b1/d490d88ab47f01f367f413bd2e47d86acf92c84157c5172c23903798bd70/Theano-1.0.3.tar.gz (2.8MB)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\ytnvj\anaconda3\lib\site-packages (from theano) (1.14.3)
# Requirement already satisfied: scipy>=0.14 in c:\users\ytnvj\anaconda3\lib\site-packages (from theano) (1.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\ytnvj\anaconda3\lib\site-packages (from theano) (1.11.0)
# Building wheels for collected packages: theano
#   Running setup.py bdist_wheel for theano: started
#   Running setup.py bdist_wheel for theano: finished with status 'done'
#   Stored in directory: C:\Users\ytnvj\AppData\Local\pip\Cache\wheels\10\82\05\9ef5e43bfcf906b4810f85f91b09d6daf7ad213d30179defa9
# Successfully built theano
# Installing collected packages: theano
# Successfully installed theano-1.0.3

# %%
# !conda install m2w64-toolchain
